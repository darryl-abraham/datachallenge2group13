# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
db_connect = sqlite3.connect("C:\\Users\\darry\\Documents\\Y2Q3_Data-Challenge-2\\dc2-policeuk.db")
cursor = db_connect.cursor()

query = "SELECT * FROM Crime WHERE DATE(Month) BETWEEN '2015-01-01' AND '2021-01-01';"
   
global df_crime

df_crime = pd.read_sql_query(query, db_connect)

cursor.close()
db_connect.close()
# Out:
#   File "<ipython-input-27-a0c358b56029>", line 13
#     return df_crime
#                    ^
# SyntaxError: 'return' outside function

# %%
df_crime
# Out:
#                                                    CrimeID       Month  \
# 0        80e07583f4bd74b85e457d92eef5d014e4e8d7b0eab0dc...  2015-01-01
# 1        6589894ebc515f501527628eb650d52a6f031116eb0ada...  2015-01-01
# 2        e6dc6a4a33ed886c7c72beaff0c5de92cc35cd2f76c6e5...  2015-01-01
# 3        b6e6462d45d0d7f4258d57628cab4c8988dc41ac675b63...  2015-01-01
# 4        769e1aa86e62b5f3c4c08c8c140147a275ca721d0801ba...  2015-01-01
# ...                                                    ...         ...
# 6458470  884fb73a6deaba5aaf4dbc09e416c32ba88715a0b77754...  2021-01-01
# 6458471  89df62aaba391a72413d8dd5458968a40a84664e268427...  2021-01-01
# 6458472  fbf7d573eb11a056d3693a31d65c37644a0c0a30fbdada...  2021-01-01
# 6458473  7cbc461d06fc1465ec9c8a7662ab47a55ee33921b188b5...  2021-01-01
# 6458474  fbf7d573eb11a056d3693a31d65c37644a0c0a30fbdada...  2021-01-01
#
#                           ReportedBy                  FallsWithin  Longitude  \
# ...

# %%
df_crime['CrimeType'].value_counts().plot.bar()

# %%
months = pd.DataFrame(pd.DatetimeIndex(df_crime['Month']).month)

# %%
months
# Out:
#          Month
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 6458470      1
# 6458471      1
# 6458472      1
# 6458473      1
# 6458474      1
#
# [6458475 rows x 1 columns]

# %%
month_dict = {1: 'January', 2 : 'February', 3: 'March', 4 : 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}
months=months.replace({"Month": month_dict})
months
# Out:
#            Month
# 0        January
# 1        January
# 2        January
# 3        January
# 4        January
# ...          ...
# 6458470  January
# 6458471  January
# 6458472  January
# 6458473  January
# 6458474  January
#
# [6458475 rows x 1 columns]

# %%
months['Month'].value_counts().plot.bar()
